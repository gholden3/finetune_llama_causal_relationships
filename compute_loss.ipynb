# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Github/finetune_llama_causal_relationships/
# Out:
# /content/drive/MyDrive/Github/finetune_llama_causal_relationships

# %%
# !git checkout -b brett
# Out:
# Switched to a new branch 'brett'

# %%
# !git push origin brett
# Out:
# Total 0 (delta 0), reused 0 (delta 0), pack-reused 0
# remote:
# remote: Create a pull request for 'brett' on GitHub by visiting:
# remote:      https://github.com/gholden3/finetune_llama_causal_relationships/pull/new/brett
# remote:
# To https://github.com/gholden3/finetune_llama_causal_relationships
#  * [new branch]      brett -> brett

# %%
# !git branch -a
# Out:
# * brett
#   main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/brett
#   remotes/origin/hanyuan
#   remotes/origin/henry
#   remotes/origin/main

# %%
# !git add .

# %%
# !git push
# Out:
# fatal: The current branch brett has no upstream branch.
# To push the current branch and set the remote as upstream, use
#
#     git push --set-upstream origin brett
